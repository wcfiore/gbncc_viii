# %%
import pint.toa as toa
import pint.residuals as res
from pint.fitter import WLSFitter
import sys
sys.path.insert(1, '/Users/william/GBNCC/gbncc_viii/data/')

import my_pint_tools as mpt
import numpy as np
from astropy import units as u
from astropy.time import Time
from pint.models import BinaryELL1, PhaseJump, parameter, get_model
from pint import binaryconvert
# %matplotlib inline

now = Time.now().to_value('ymdhms')
curdat = f'{now[1]:02}{now[2]}{str(now[0])[2:]}'

# %% [markdown]
# # Pulsar timing notebook for J0032+6946 using "ELL1++"

# %% [markdown]
# ### Step 1: create TOAs and model from files
#
# Run this to start/restart timing process.

# %%
tim='/Users/william/GBNCC/gbncc_viii/data/J0032+6946_fiore+23.tim'
par='/Users/william/GBNCC/gbncc_viii/data/J0032+6946_fiore+23.par'
toas=toa.get_TOAs(tim,usepickle=False,planets=True,ephem="DE440");
model=mpt.mod.get_model(par);
# Out:
# 2023-05-11 14:59:58.738 | DEBUG    | pint.toa:__init__:1340 - No pulse number flags found in the TOAs
# 2023-05-11 14:59:58.746 | DEBUG    | pint.toa:apply_clock_corrections:2182 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2023-05-11 14:59:58.921 | INFO     | pint.observatory:gps_correction:209 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2023-05-11 14:59:58.922 | INFO     | pint.observatory:_load_gps_clock:92 - Loading global GPS clock file
# 2023-05-11 14:59:58.930 | DEBUG    | pint.observatory.clock_file:__init__:799 - Global clock file gps2utc.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2023-05-11 14:59:58.948 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:456 - Loading TEMPO2-format observatory clock correction file gps2utc.clk (/Users/william/.astropy/cache/download/url/d3c81b5766f4bfb84e65504c8a453085/contents) with bogus_last_correction=False
# 2023-05-11 14:59:59.034 | INFO     | pint.observatory:find_clock_file:918 - Using global clock file for gps2utc.clk with bogus_last_correction=False
# 2023-05-11 14:59:59.039 | INFO     | pint.observatory:bipm_correction:216 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2023-05-11 14:59:59.040 | INFO     | pint.observatory:_load_bipm_clock:103 - Loading BIPM clock version bipm2021
# 2023-05-11 14:59:59.044 | DEBUG    | pint.observatory.clock_file:__init__:799 - Global clock file tai2tt_bipm2021.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2023-05-11 14:59:59.057 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:456 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2021.clk (/Users/william/.astropy/cache/download/url/e00edeef4edde217d65207a9abeb6a8c/contents) with bogus_last_correction=False
# 2023-05-11 14:59:59.085 | INFO     | pint.observatory:find_clock_file:918 - Using global clock file for tai2tt_bipm2021.clk with bogus_last_correction=False
# 2023-05-11 14:59:59.097 | DEBUG    | pint.observatory.clock_file:__init__:799 - Global clock file time_gbt.dat saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2023-05-11 14:59:59.133 | DEBUG    | pint.observatory.clock_file:read_tempo_clock_file:600 - Loading TEMPO-format observatory clock correction file time_gbt.dat (/Users/william/.astropy/cache/download/url/599e3ebbfc317e090244ee1ef4c79374/contents) with bogus_last_correction=False
# 2023-05-11 14:59:59.218 | INFO     | pint.observatory:find_clock_file:918 - Using global clock file for time_gbt.dat with bogus_last_correction=False
# 2023-05-11 14:59:59.219 | INFO     | pint.observatory.topo_obs:clock_corrections:342 - Applying observatory clock corrections for observatory='gbt'.
# 2023-05-11 15:00:00.259 | DEBUG    | pint.toa:compute_TDBs:2233 - Computing TDB columns.
# 2023-05-11 15:00:00.260 | DEBUG    | pint.toa:compute_TDBs:2254 - Using EPHEM = DE440 for TDB calculation.
# 2023-05-11 15:00:00.627 | DEBUG    | pint.toa:get_TOAs:307 - Planet PosVels will be calculated.
# 2023-05-11 15:00:00.628 | DEBUG    | pint.toa:compute_posvels:2327 - Computing PosVels of observatories, Earth and planets, using DE440
# 2023-05-11 15:00:00.711 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:01.898 | DEBUG    | pint.toa:compute_posvels:2385 - SSB obs pos [ 1.46988260e+11 -3.19153333e+10 -1.38535450e+10] m
# 2023-05-11 15:00:01.899 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:01.905 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:01.910 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.025 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.030 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.037 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.056 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.095 | DEBUG    | pint.toa:compute_posvels:2399 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# /Users/william/PINT/src/pint/pulsar_mjd.py:364: RuntimeWarning: overflow encountered in conversion from string
#   return np.longdouble(str_data.translate(maketrans("Dd", "ee")))

# %%
#### Remove TOAs if need be, look at the model

# "permanently" remove TOAs here 
#toas = mpt.mask_toas(toas,before=56500)

# "first look"

toas.compute_pulse_numbers(model)

mpt.plot_fit(toas,model)
# Out:
# 2023-05-11 15:00:02.653 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:96 - Creating and dealing with the single TZR_toa for absolute phase
# 2023-05-11 15:00:02.658 | DEBUG    | pint.toa:__init__:1340 - No pulse number flags found in the TOAs
# 2023-05-11 15:00:02.661 | DEBUG    | pint.toa:apply_clock_corrections:2182 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2023-05-11 15:00:02.665 | INFO     | pint.observatory:gps_correction:209 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2023-05-11 15:00:02.669 | INFO     | pint.observatory:bipm_correction:216 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2023-05-11 15:00:02.671 | INFO     | pint.observatory.topo_obs:clock_corrections:342 - Applying observatory clock corrections for observatory='gbt'.
# 2023-05-11 15:00:02.675 | DEBUG    | pint.toa:compute_TDBs:2233 - Computing TDB columns.
# 2023-05-11 15:00:02.677 | DEBUG    | pint.toa:compute_TDBs:2254 - Using EPHEM = DE440 for TDB calculation.
# 2023-05-11 15:00:02.723 | DEBUG    | pint.toa:compute_posvels:2327 - Computing PosVels of observatories, Earth and planets, using DE440
# 2023-05-11 15:00:02.736 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.803 | DEBUG    | pint.toa:compute_posvels:2385 - SSB obs pos [ 1.46988260e+11 -3.19153333e+10 -1.38535450e+10] m
# 2023-05-11 15:00:02.810 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.816 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.834 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.848 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.858 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.872 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.890 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:02.899 | DEBUG    | pint.toa:compute_posvels:2399 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2023-05-11 15:00:02.906 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:118 - Done with TZR_toa

# %%
#### Do the fit

#model = f.model

f=WLSFitter(toas,model,track_mode='use_pulse_numbers')

# BT params #
f.model.free_params=['F0','F1','RAJ','DECJ','DM','FB0','TASC','A1','EPS1','EPS2']

f.fit_toas(maxiter=1)
mpt.plot_fit(toas,f.model)
f.print_summary()
f.model.compare(model,verbosity='check')
# Out:
# 2023-05-11 15:00:07.686 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:96 - Creating and dealing with the single TZR_toa for absolute phase
# 2023-05-11 15:00:07.691 | DEBUG    | pint.toa:__init__:1340 - No pulse number flags found in the TOAs
# 2023-05-11 15:00:07.693 | DEBUG    | pint.toa:apply_clock_corrections:2182 - Applying clock corrections (include_gps = True, include_bipm = True)
# 2023-05-11 15:00:07.699 | INFO     | pint.observatory:gps_correction:209 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2023-05-11 15:00:07.706 | INFO     | pint.observatory:bipm_correction:216 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2023-05-11 15:00:07.758 | INFO     | pint.observatory.topo_obs:clock_corrections:342 - Applying observatory clock corrections for observatory='gbt'.
# 2023-05-11 15:00:07.768 | DEBUG    | pint.toa:compute_TDBs:2233 - Computing TDB columns.
# 2023-05-11 15:00:07.769 | DEBUG    | pint.toa:compute_TDBs:2254 - Using EPHEM = DE440 for TDB calculation.
# 2023-05-11 15:00:07.801 | DEBUG    | pint.toa:compute_posvels:2327 - Computing PosVels of observatories, Earth and planets, using DE440
# 2023-05-11 15:00:07.811 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.831 | DEBUG    | pint.toa:compute_posvels:2385 - SSB obs pos [ 1.46988260e+11 -3.19153333e+10 -1.38535450e+10] m
# 2023-05-11 15:00:07.833 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.838 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.842 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.847 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.850 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.854 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.857 | INFO     | pint.solar_system_ephemerides:load_kernel:127 - Set solar system ephemeris to de440 through astropy
# 2023-05-11 15:00:07.863 | DEBUG    | pint.toa:compute_posvels:2399 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2023-05-11 15:00:07.869 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:118 - Done with TZR_toa
# 2023-05-11 15:00:09.515 | INFO     | pint.models.timing_model:compare:1987 - Comparing ephemerides for PSR J0032+6946
# 2023-05-11 15:00:09.515 | DEBUG    | pint.models.timing_model:compare:1988 - Threshold sigma = 3.00
# 2023-05-11 15:00:09.516 | DEBUG    | pint.models.timing_model:compare:1989 - Threshold uncertainty ratio = 1.05
# 2023-05-11 15:00:09.517 | DEBUG    | pint.models.timing_model:compare:1990 - Creating a copy of model from J0032+6946_fiore+23.par
# 2023-05-11 15:00:09.518 | DEBUG    | pint.models.timing_model:compare:2000 - Check verbosity - only warnings/info will be displayed
# 2023-05-11 15:00:09.544 | WARNING  | pint.models.timing_model:compare:2192 - Parameter ECC not fit, but has changed between these models
# 2023-05-11 15:00:09.547 | WARNING  | pint.models.timing_model:compare:2192 - Parameter OM not fit, but has changed between these models
# Fitted model using weighted_least_square method with 10 free parameters to 1430 TOAs
# Prefit residuals Wrms = 19.107536061887988 us, Postfit residuals Wrms = 19.107535864985035 us
# Chisq = 1419.530 for 1419 d.o.f. for reduced Chisq of 1.000
#
# PAR                        Prefit                  Postfit            Units
# =================== ==================== ============================ =====
# PSR                           J0032+6946 J0032+6946                   None
# EPHEM                              DE440 DE440                        None
# CLOCK                       TT(BIPM2021) TT(BIPM2021)                 None
# UNITS                                TDB TDB                          None
# START                            55169.2                      55169.2 d
# FINISH                           58303.4                      58303.4 d
# TIMEEPH                             FB90 FB90                         None
# T2CMETHOD                       IAU2000B IAU2000B                     None
# BINARY                              ELL1 ELL1                         None
# DILATEFREQ                             N                              None
# DMDATA                                 N                              None
# NTOA                                1430                              None
# CHI2                                   0
# POSEPOCH                           56736                              d
# PX                                     0                              mas
# RAJ                    0h32m41.24767642s  0h32m41.24767642s +/- 0.00028 hourangle_second
# DECJ                  69d46m28.04696008s  69d46m28.04696007s +/- 0.0017 arcsec
# PMRA                                   0                              mas / yr
# PMDEC                                  0                              mas / yr
# F0                               27.1711         27.1711195724922(25) Hz
# PEPOCH                             56736                              d
# F1                          -2.65006e-15          -2.650056(30)×10⁻¹⁵ Hz / s
# TZRMJD                           56909.7                              d
# TZRSITE                                1 1                            None
# TZRFRQ                           377.699                              MHz
# CORRECT_TROPOSPHERE                    Y                              None
# PLANET_SHAPIRO                         Y                              None
# NE_SW                                  4                              1 / cm3
# SWP                                    2
# SWM                                    0
# DM                               79.9988                 79.99881(21) pc / cm3
# DMEPOCH                            56736                              d
# PBDOT                                  0
# A1                               178.675              178.6747682(29) ls
# A1DOT                                  0                              ls / s
# EDOT                                   0                              1 / s
# OMDOT                                  0                              deg / yr
# FB0                          2.19363e-08          2.193632768(6)×10⁻⁸ 1 / s
# TASC                             56399.1              56399.134959(4) d
# EPS1                         0.000285545              0.000285545(16)
# EPS2                        -0.000448653             -0.000448653(30)
# EPS1DOT                                0                              1e-12 / s
# EPS2DOT                               -0                              1e-12 / s
# ECC                          0.000531813
# OM                               147.525                              deg
# EFAC1                             1.0803
# EFAC2                             1.0803
#
# Derived Parameters:
# Period = 0.03680378341908257 s +/- 3.43802778884024e-15 s
# Pdot = 3.5895502123740925e-18 +/- 4.044084304770691e-23
# Characteristic age = 1.624e+08 yr (braking index = 3)
# Surface magnetic field = 1.16e+10 G
# Magnetic field at light cylinder = 2114 G
# Spindown Edot = 2.843e+33 erg / s (I=1e+45 cm2 g)
#
# Binary model BinaryELL1
# Orbital Period  (PB) = 527.6213158148644 d +/- 1.5394426098362518e-06 d
# Conversion from ELL1 parameters:
# ECC = 0.000531813±0.000000027
# OM  = 147.5253±0.0023 deg
# T0  = 56615.3502(33)
# Checking applicability of ELL1 model --
#     Condition is asini/c * ecc**4 << timing precision / sqrt(# TOAs) to use ELL1
#     asini/c * ecc**4    = 1.43e-05 us
#     TRES / sqrt(# TOAs) = 0.505 us
#     Should be fine.
#
# Mass function = 0.0220002565(11) Msun
# Min / Median Companion mass (assuming Mpsr = 1.4 Msun) = 0.4173 / 0.4956 Msun

# %%
#### Update model, go back a step if further fitting needed

model=f.model

newtoas = toas

newtoas.compute_pulse_numbers(model)

mpt.plot_fit(newtoas,f.model)

# %%
# save model to file
parfile=model.PSR.value+'_upd'+curdat+'.par'
timfile=model.PSR.value+'_upd'+curdat+'.tim'


mpt.write_partim(model=model,parfile=parfile,toas=newtoas,timfile=timfile,overwrite=True,final_dir='./data/')
# Out:
# ./data/J0032+6946_upd05923.par written
# ./data/J0032+6946_upd05923.tim written

# %%
residuals = f.resids.resids.to(u.us).value
errs = f.resids.get_data_error().to(u.us).value
mjds = newtoas.get_mjds().value
freqs = newtoas.get_freqs().value
fnames = newtoas['name']
outfile = "/Users/william/GBNCC/gbncc_viii/data/J0032+6946_residuals.dat"
with open(outfile, "w") as f:
    for r,e,m,n in zip(residuals,errs,mjds,freqs):
        line = f"{r} {e} {m} {n}\n"
        f.write(line)
